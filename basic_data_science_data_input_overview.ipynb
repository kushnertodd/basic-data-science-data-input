# %% [markdown]
# # Python Data Input

# %% [markdown]
# # Snippets
# - [Snippets](https://colab.research.google.com/github/kushnertodd/basic-data-science-data-input/blob/main/Snippets_Accessing_files.ipynb)

# %% [markdown]
# # Reading a text file
# - [Text file](https://colab.research.google.com/github/kushnertodd/basic-data-science-data-input/blob/main/basic_data_science_data_input_text_files.ipynb): sequences of text characters
# - [file processing example](https://colab.research.google.com/github/kushnertodd/basic-data-science-data-input/blob/main/file_processing.ipynb)

# %% [markdown]
# # Reading a file from `github`

# %% [markdown]
# # Reading a `csv` file

# %%
# Reading from a SQL database
