# %% [markdown]
# # Python Data Input

# %% [markdown]
# # Reading a text file

# %% [markdown]
# # Reading a file from `github`

# %% [markdown]
# # Reading a `csv` file

# %%
# Reading from a SQL database
